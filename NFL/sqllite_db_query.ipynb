# %%
import pandas as pd
import sqlite3

DATABASE_NAME = 'odds.db'

conn = sqlite3.connect(DATABASE_NAME)
table_name = 'player_props'
df = pd.read_sql(f'''SELECT * FROM {table_name}''', conn)
# Out:
#                            event_id                             event_name  \
# 0  e10fe83ee6178a598e7fa84ea0913366  Philadelphia Eagles @ New York Giants
# 1  e10fe83ee6178a598e7fa84ea0913366  Philadelphia Eagles @ New York Giants
# 2  e10fe83ee6178a598e7fa84ea0913366  Philadelphia Eagles @ New York Giants
# 3  e10fe83ee6178a598e7fa84ea0913366  Philadelphia Eagles @ New York Giants
# 4  e10fe83ee6178a598e7fa84ea0913366  Philadelphia Eagles @ New York Giants
#
#               sport_key        market_type outcome_type     player_name  \
# 0  americanfootball_nfl  player_anytime_td          Yes  Saquon Barkley
# 1  americanfootball_nfl  player_anytime_td          Yes     Jalen Hurts
# 2  americanfootball_nfl  player_anytime_td          Yes    Cam Skattebo
# 3  americanfootball_nfl  player_anytime_td          Yes        AJ Brown
# 4  americanfootball_nfl  player_anytime_td          Yes   DeVonta Smith
#
#    point_value   odds      event_commence_time             updated_dttm
# ...

# %%
df[(df['player_name'] == 'Jalen Hurts') & (df['market_type'] == 'player_pass_yds')]
# Out:
#                             event_id                             event_name  \
# 50  e10fe83ee6178a598e7fa84ea0913366  Philadelphia Eagles @ New York Giants
# 51  e10fe83ee6178a598e7fa84ea0913366  Philadelphia Eagles @ New York Giants
#
#                sport_key      market_type outcome_type  player_name  \
# 50  americanfootball_nfl  player_pass_yds         Over  Jalen Hurts
# 51  americanfootball_nfl  player_pass_yds        Under  Jalen Hurts
#
#     point_value   odds      event_commence_time             updated_dttm
# 50        199.5 -115.0  2025-10-09 20:15:00 EDT  2025-10-09 13:20:06 EDT
# 51        199.5 -115.0  2025-10-09 20:15:00 EDT  2025-10-09 13:20:06 EDT
